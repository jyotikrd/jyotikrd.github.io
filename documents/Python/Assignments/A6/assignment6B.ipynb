# %% [markdown]
# #**6B.**
#
# Write a program to display the index of a line (assume index starts with 0) which contains most number of words in `file6B.txt`
#
# Also display the average words per line in the file.
