# %% [markdown]
# Ask the user for a sentence (string). Find words with 3 or more than 3 occurences in the sentence.
#
# e.g `"This is The most common word used in the the common language of the people in this city at this time"`
#
# here, we want the following result with number of occurences
#
# `the:3 this:3`
#
# > **Note:** "This" and "this" are considered the same word.
#
# > **Assumption:** there will be no other characters in the string other than alphabets(Aa-Zz) and the `" "`(space) character.
#
#
# **Hint 1:** Convert the string to list of words ensuring no case-sensitivity. Think of `.split()` and `.lower()` string methods
#
# **Hint 2:** Create a dictionary which maps a word to its number of occurences. Use sets to remove duplicates.
#
#
#
# **Output list must be sorted alphabetically to make it easier for grading**

# %%
##########################################################################################################
# Important point ::::                                                                                  ##
                                                                                                        ##
# Converting any list to a set and then again to list                                                   ##
# will change the order of the elements in the list,                                                    ##
# as the intermediate set will be scrambled randomly                                                    ##
# therefore, to not create conflicts in the received answers and our answer, we ask for a sorted list.  ##
                                                                                                        ##
##########################################################################################################


# Step 1: Ask user for a string. Also, see the assumption in question above.
sentence = 



# Step 2: Create word list from above sentence string. Also, see HINT 1
wordList = 




# Step 3: Populate dictionary wordCount with unique words from wordList. See HINT 2
#         Think set() and count()
wordCount = {}

  



# Step 4: Populate finalList with keys from wordCount dictionary that has value>=3 (occurences in the sentence)
finalList = []





# Step 5: Print the sorted finalList. Think sorted()
