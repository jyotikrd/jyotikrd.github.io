# %% [markdown]
# # Temperature Conversion
#
# In this activty you will learn, how to convert the temperature from Celcius (C) to Fahrenheit (F) or vice versa. There will be an extension of this program in the future assignment. So it is necessary for you to practice this problem well. For this assignment we are expecting you to use 2 variables.
#
# ![alt text](https://images.slideplayer.com/18/6092884/slides/slide_1.jpg)

# %% [markdown]
# # Convert F to C
# Wite a program to ask for user-input temperature (in F) and display the equivalent temperature in Celsius (C)
#
# Ensure **1 decimal place** for all output values
#
# **Example:**
#
#
# ```
# Enter Temperature in F:
# Equivalent temperature in C is ?
# ```

# %% [markdown]
# # Convert C to F
# Wite a program to ask for user-input temperature (in Celsius) and display the equivalent temperature in Fahrenheit (F)
#
# Ensure **1 decimal place** for all output values
#
#
# **Example:**
#
# ```
# Enter Temperature in C:
# Equivalent temperature in F is ?
# ```
