# %% [markdown]
# ### Boolean Operators
#
# Programming languages give us access to operators that can compare something. That might not always be enough, sometimes we might need to combine comparisions, or know whether one or all of many comparisions are True. Thus, we need something that will work with Boolean values
#
# To help us with that, Python lets us use the following operators to work with Boolean values:
#
# | Operator | Usage   | Result                                                 |
# |----------|---------|--------------------------------------------------------|
# | and      | `A and B` | True if both A & B are True, False otherwise           |
# | or       | `A or B`  | True if atleast one of A / B is true, False otherwise  |
# | not      | `not A`   | "Negation": True if A is False, False if A is True     |

# %% [markdown]
# **Fluffy in London**
#
# Fluffy is in London on vacation and plans to visit the Tower Museum of London.
#
# Let's look at how we'd express various situations with the Tower bridges for Fluffy to cross the Thames river.
#
# We will be using boolean variables & boolean operators to represent the situations and the result
#
# **CASE A:** Bridges in serial
# ![picture](https://drive.google.com/uc?id=1oi4rmUjpmfhnB-Mza7XuKDtxWkKRb8Qw)

# %%
# Problem: Let's say we have two Tower bridges that separate our
# dog, Fluffy, from visiting the Tower Museum of London.
# Let's look at how we'd express various situations with boolean values & operators. 

# Let us represent statuses of both bridges being down as two boolean variables
# bridge_1_down, bridge_2_down.
bridge_1_down = True
bridge_2_down = False

# CASE A: If bridges are in serial over Thames river, we need both bridges to be down for Fluffy to cross:

can_cross_A = bridge_1_down and bridge_2_down
# Explanation: Bridge 1 bascules should be down AND Bridge 2 bascules should be down

print(can_cross_A)

# Play with all bool combinations of bridge_1_down, bridge_2_down

# %% [markdown]
# **CASE B:** Bridges in Parallel
# ![picture](https://drive.google.com/uc?id=1am4womIqyuujkJGwC641jQ8Ey3Sb_R6S)

# %%
bridge_1_down = True
bridge_2_down = False

# CASE B: If bridges are in parallel over Thames river, we need atleast one bridge to be down for Fluffy to cross:

can_cross_B = bridge_1_down or bridge_2_down
# Explanation: Bridge 1 bascules should be down OR Bridge 2 bascules should be down

print(can_cross_B)

# Try with other possible values for bridge_down bridge_1_ down, bridge_2_down

# %% [markdown]
# **CASE C:** Bridge, ShiP, and LuLu
#
# ![picture](https://drive.google.com/uc?id=1hJH5usltJyN4Aq5i8vnxdNj5atZlm_7m)

# %%
# In reality, there is only one Tower bridge over Thames.
bridge_down = True

# CASE C:
# Suppose, in addition to the Tower bridge, there is a new ShiP service to cross the Thames to visit Tower museum of London.
# Fluffy's girlfriend LuLu is waiting on the other side of bridge and plans to take him Shopping instead.
# For Fluffy to fulfill his desire to visit the museum, 
# he hopes that Bridge bascules are up so that LuLu doesn't see him on the other side of the bridge

can_cross_C = not bridge_down
# Explanation: Bridge bascules should be up (not down) so that LuLu doesn't see him on the other side of the bridge

print(can_cross_C)

# Try with other value for bridge_down

# %% [markdown]
# ### Complex Conditions
#
# Often in your programs, you'll find a need to 'chain' multiple conditions, or execute a block of code if one of many _different_ conditiosn are met.
#
# In that case, you can combine the knowledge of Boolean Operators and conditionals to write complex conditions

# %%
# Problem: Let's say we can either cross the Thames river using the two bridges we talked about
# before, or use the new ShiP that has just launched. But the latter costs money.
# We can try and represent this in terms of boolean values and operators

bridge_1_down = True
bridge_2_down = False

ship_cost = 5
money_in_wallet = 7

can_cross = (bridge_1_down and bridge_2_down) or (money_in_wallet >= ship_cost)
# Explanation: We can cross if both bridges have their bascules down OR if we have enough money
# for the ShiP.

print(can_cross)

# Play with adifferent values of all the four variables above to see the final result

# %% [markdown]
# #### **Exercise 1: Writing Boolean Expressions**
#
# We can convert natural language sentences that represent conditions into boolean expressions.
#
# For example, the sentence *Fluffy can cross the river IF both the bridges are down* was converted into the Boolean expression:
#
# `fluffy_can_pass_1 = bridge_1_down and bridge_2_down`
#
# Let's practice more of such conversions in the next code cell:

# %%
# Exercise 1.1: Taking out a loan
# You can take out a loan when any one or more (atleast) of these conditions is met:
#   * You have a bank balance greater than 10% of the loan amount
#   * You have a house worth atleast twice the loan amount as collateral
# Given the variables below, can you create a boolean expression that shows
# whether your loan will be approved or not?

loan_amount = 100000
bank_balance = 9500
house_value = 210000

can_get_loan = # Enter your boolean expression here
print(can_get_loan)

# %% [markdown]
# ### Branching
#
# The ability to make decisions based on a condition is one of the core abilities of a program or let's say LIFE.
#
# * In an inventory-tracking program, you might want to block all purchases and send a notification to the owner once the stock of an item reaches zero.
# * In a stock trading application, you might want to automatically sell the stock when the value goes above / below a given value.
#
# And many other instances. Python gives us the ability to make such decisions, called _Branching_ or _Conditionals_. The most simple example of Conditionals is the `if` block.

# %%
# Going back to the lecture, consider our dog, Fluffy, that wanted to cross over those
# two bridges.
# We want to print out a message if it can pass the bridge.

# Try changing these values and run the block again to see how the output changes.
bridge_1_down = True
bridge_2_down = False

# We need both bridges to be down for Fluffy to cross Thames.
can_cross = bridge_1_down and bridge_2_down

if can_cross:
  print("Fluffy can cross the Thames! 🙂")

# Note the indentation of the print statements. That signifies that the statements
# are inside a 'block' of code, which here is an 'if' block

# %% [markdown]
# Let's say we have different things to do when a condition is met vs when it _isn't_, then we can use the `else` block.

# %%
# We want to print out a message with 🙂 if it can cross the Thames else other with 😭 if it cannot.

# Try changing these values and run the block again to see how the output changes.
bridge_1_down = True
bridge_2_down = False

# We need both bridges to be down for Fluffy to cross Thames.
can_cross = bridge_1_down and bridge_2_down

if can_cross:
  print("Fluffy can cross the Thames! 🙂")
else:
  print("Fluffy can not cross the Thames! 😭 ")

# %% [markdown]
# There might be cases where if a given condition isn't met, you might want to check another condition and run some code if the latter condition is `True`. For such a case, we have the `elif` block.
# This is a short form of the phrase 'else if'.

# %%
# Problem: Going back to the lecture, consider our dog, Fluffy, that wanted to cross over those
# two bridges. 
# We want to print out a message in the following cases:
#   * If Fluffy crossed the Thames!
#   * If Fluffy can cross Half-way with the FIRST bridge
#   * If Fluffy can not cross the Thames and is stuck on other side

# Try changing these values and run the block again to see how the output changes.
bridge_1_down = True
bridge_2_down = False

# We need both bridges to be closed for Fluffy to cross the Thames.
can_cross = bridge_1_down and bridge_2_down
 
if can_cross:
  print("Fluffy crossed the Thames! 🙂")
elif bridge_1_down: # This runs if ONLY bridge 1 is down. Can you tell how?
  print("Fluffy made it half-way over Thames! 🙌")
else:
  print("Fluffy can not cross the Thames and is stuck on other side! 😭")

# %% [markdown]
# You can also have multiple `elif` blocks following an `if` block.

# %%
# Problem: Let's say we want to convert a numeric grade into a letter grade.
# This code block shows how we can do that with conditionals.

# Try changing this value and see how to output changes
grade = 92

if grade >= 90:
  print("You got an !")
elif grade >= 80: # This block checks if 80 <= grade < 90. Can you tell how?
  print("You got a B")
elif grade >= 70:
  print("You got a C")
else:
  print("Better luck next time!")

# %% [markdown]
# #### **Exercise 2: Calculator Extension from Assignment 0**
#
# In Assignment 0, we had an example of a calculator which could only do addition and subtraction. Now that we know how to work with conditionals, we can try and add more functionality to it!
#
# Look at the code below, which contains the `calculator` function that already implements the `+` and `-` operators. Add code to it to handle the following operators:
# * Division: `/` (the key will be `'/'`)
# * Multiplication: `*` (the key will be `'*'`)
# * Modulus: `%` (the key will be `'%'`)

# %%
# define a calculator function
def calculator(a, b, key):
  
  # Already implements addition and subtraction
  if(key == '+'):  # if value of key is +, perform addition
    print("Sum is ",a+b)
  elif(key == '-'):           # else if value of key is -, perform subtraction
    print("Difference is ",a-b)
  
  # Write more functionality!

# Call the calculator with the new user-input operators!
key_user = input("Enter which operator (+ - / * %)")
calculator(120, 12, key_user)

# %% [markdown]
# ### Nested Conditionals
#
# Sometimes you might need to check a condition _after_ you know another condition has already been met. Maybe you see that a customer has enough money for a product, but want to know if they have enough money for you to recommend a deal to them.
#
# In such cases, you can _nest_ conditional blocks. They are just like normal conditional blocks, but inside another block.
#
# **Note:** As you can see below, the statements inside the nested conditional block are indented _twice_. As a rule, if a statement is supposed to be inside an _nth_ nested block, the statement should be indented _n_ times.

# %%
# Problem: We wrote code for converting a numeric grade -> letter grade. Now we
# might want more granularity in the letter grades with 'A+', 'B-' and so on.

# This code block shows how we can do that with nested conditionals.

grade = 82

if grade >= 90:
  if grade >= 95:
    print("You have an A+")
  else:
    print("You have an A-")
elif grade >= 80: 
  if grade >= 85:
    print("You have an B+")
  else:
    print("You have an B-")

# Note: Your conditonal blocks don't always have to end with `else` an `elif` block
# can be the last one too! But if an `else` block does exist, it need to be at the
# end.

# %% [markdown]
# #### **Exercise 3: Dora's Exploration**
#
# Let's try and implement the example we discussed in class about Dora exploring new terrains on her way back to home. Here's a pictoral representation of the problem at hand:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# We'll take the 'explore' value as Dora's input, and then print out what route she explored on her way back home.

explore = input("What do you want to explore? (forest, mountains, zoo)")

# Add the appropriate conditions in the if / elif blocks below and run the cell!

if ? : # Add condition in place of ?
    if ? : # Add condition in place of ?.
        print("I explored the Forest", end=" ")
    else:
        print("I explored the Mountains", end=" ")   
elif ? : # Add condition in place of ?.
    print("I explored the Zoo", end=" ")

print("on my way to Home")

# Also try user-input which is neither of (forest, mountains, zoo)

# %% [markdown]
# #### **Exercise 4: Sign of a Number**
#
# ![alt text](https://cdn.kastatic.org/ka-perseus-images/5a9c5aa808aebee57536296b29fdc27b885e4a5a.svg)

# %%
# Convert the above conditional flowchart into code to display sign of the number

number = int(input())



print(f"Sign of {number} is {sign_number}")

# %% [markdown]
# ### Conditional Assignment
# Sometimes you might have a branch that is essentially the same code with a different expression.  For cases like this, python has conditional expressions ( or assignment)
#
# They can be thought of as a condensed form of a basic `if / else` block. Other languages have similar statements called _ternary statements_.

# %%
# Problem: Going back to our example of Fluffy trying to cross the Thames with two bridges in Series.
# Let's try and print out something for the cases where Fluffy can / can not cross
# the bridges, but using Conditional Expressions this time around.

bridge_1_down = True
bridge_2_down = False

# CASE A: Bridges in Series
can_cross = bridge_1_down and bridge_2_down

sentence_to_print = "Fluffy crossed the Thames! 🙂" if can_cross else "Fluffy can not cross the Thames! 😭"
print(sentence_to_print)
