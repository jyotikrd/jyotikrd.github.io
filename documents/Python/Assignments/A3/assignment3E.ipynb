# %% [markdown]
# # Highest Common Factor (HCF)
#
# Write a program that accepts two non-negative integers, `x` and `y` from the user and prints the HCF(x,y)
#
# Input
# ```
# 15
# 10
# ```
# output
# ```
# 5
# ```
