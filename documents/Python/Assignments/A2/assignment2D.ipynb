# %% [markdown]
# #Grade Calculator
#
# In this activity, you will learn how to use if-elif-else.
#
# You are expected to take three inputs from the user of three test scores (Assume each test score to be out of 100). Calculate the average of these three tests and calculate the final letter grade based on the following grading criteria.
#
# ![alt text](https://drive.google.com/uc?id=1leu5hRzkVpqUx_24-zCcIYAmCJlbHFVo)
#
# Expected Output:
#
# ```
# Average Score: ___
# Final Letter Grade: __
# ```
#
# Example:
#
# Suppose, the user enters 90, 93, 86 for the test scores. Then,
#
# # $$ Average Score = \frac{90+93+86}{3} = 89.67$$
#
# Therefore, the Final Letter Grade will be A.

# %%
g=(99+95.5+90)/3
print(f"{g:.2f}")
# Out:
# 94.83
