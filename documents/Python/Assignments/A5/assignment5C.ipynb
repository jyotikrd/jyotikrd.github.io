# %% [markdown]
# Given a string, it is said to be a Palindrome if the string reads the same backward as forward.
#
# Write a function that takes a string as an input and returns True/False if the string is Palindrome or not.
#
# **Note: **
#
# *   User-input String
# *   Assume Input consists of no numbers
# *   Please consider case sensitivity when determining a Palindrome.
# *   Ignore any punctuations(including spaces) when determining a Palindrome.
#
# **Examples:**
#
# ***my gym*** input should have output as
# ```
# True
# ```
#
#
# ---
#
#
# ***my Gym*** input should have output as
# ```
# True
# ```
# G happens to be same in reversed string
#
# ---
#
#
# ***my gym !*** input should have output as
# ```
# True
# ```
# Punctuations should be ignored
#
# ---
#
# ***My gym*** input should have output as
# ```
# False
# ```
# M is upper case while reverse string has m
#
# ---

# %%
# Write your code below
