# %% [markdown]
# # Prime Check
#
# Write a program to find if a non-negative number entered by the user `n`
#  is prime number (Yes) or composite number (No) or neither (Neither). Remember, a prime number is a number with only two factors, 1 and the number itself.
#
#  Input
# ```
# 4
# ```
# Output
#
#
# ```
# No
# ```
