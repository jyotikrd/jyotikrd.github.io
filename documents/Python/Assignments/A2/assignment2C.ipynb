# %% [markdown]
# # Currency Denomination
#
# This assignment will help you better understanding of the conditionals and expressions in the python. This is the extension of the previous assignment.
#
# Your Program should accept user-input amount between \$0 and \$1000 (\$0.00 to \$999.99) and then display the minimum amount of denomination required to fulfill this number.
#
# Expected Output (Display non-zero denominations ONLY):
# ```
# $_____ amounts to
# ___: $100 bills
# ___: $50 bills
# ___: $20 bills
# ___: $10 bills
# ___: $5 bills
# ___: $1 bills
# ___: 25 cents
# ___: 10 cents
# ___: 5 cents
# ___: 1 cent
# ```
#
# Example Output 1:
# ```
# $756.83 amounts to
# 7: $100 bills
# 1: $50 bills
# 1: $5 bills
# 1: $1 bills
# 3: 25 cents
# 1: 5 cents
# 3: 1 cent
# ```
#
# Example Output 2:
# ```
# $123.80 amounts to
# 1: $100 bills
# 1: $20 bills
# 3: $1 bills
# 3: 25 cents
# 1: 5 cents
# ```

# %%
input_number = float(input('Enter the number:')

if(input_number//100>0)
  print(input_number//100, ':$100 bills')
