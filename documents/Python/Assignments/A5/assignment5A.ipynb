# %% [markdown]
# Write a function that calculates and returns the circumference and area of a circle for user-input radius. Outputs should have precision of 2 decimal places.
#
# Ensure the radius is positive quantity. For invalid values, print
#
# ```
# Invalid Radius
# ```
#
#
#
#
# **Output**
# ```
# Circumference: _______ cm
# Area: _____ cm square
# ```

# %% [markdown]
# **BONUS**
#
# If the user input is invalid, keep asking the user to input valid radius unless a valid value is presented. Then print the Circumference and Area of that circle.
