# %% [markdown]
#  **Given below is the worktime of 50 employees in an IT services company in India.
# Overtime is paid at the rate of Rs. 15.00 per hour for every
# hour worked above some `x` hours.
# Your job is to calculate the total cost that the company has to pay considering the overtime of all workers**
#
# ```# The 50 employees have following work hours logged into the system
# work_hours = [53, 21, 58, 52, 33, 39, 49, 18, 36, 15, 49, 26, 53, 26, 40, 32, 43, 55, 42,35, 45, 21, 42, 18, 60,
#             34, 41, 40, 31, 22, 57, 59, 25, 53, 51, 49, 37, 49, 41, 33, 32, 49, 39, 26, 52, 18, 44, 48, 55, 23]
# ```
# e.g.
# If the overtime starts after x=40 work hours,
# then the total amount the company has to pay is Rs. 3735.00, as per Rs. 15 per hour overtime.

# %%
# The 50 employees have following work hours logged into the system
work_hours = [53, 21, 58, 52, 33, 39, 49, 18, 36, 15, 49, 26, 53, 26, 40, 32, 43, 55, 42,35, 45, 21, 42, 18, 60,
            34, 41, 40, 31, 22, 57, 59, 25, 53, 51, 49, 37, 49, 41, 33, 32, 49, 39, 26, 52, 18, 44, 48, 55, 23]

# Write your code below where x is user-input
