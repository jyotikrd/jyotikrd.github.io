# %% [markdown]
# # Calculate the Simple Interest
# In this activity you will learn how to calculate simple interest and use of different variables and expression. In this activity you are expected to take 3 different input from the user of amount on which interest should be calculated, interest rate, and the time period for the interest.
#
# ![alt text](https://getcalc.com/formula/finance/si-simple-interest.png)
#
# Final Amount = P + SI
#
# Output expected (ensure 2 decimal places):
#
# ```
# Simple interest calculated is $_______
# Final amount calculated is $______
# ```
