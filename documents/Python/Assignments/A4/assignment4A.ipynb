# %% [markdown]
# > **Given below are some of the ages of people in a study of population on the planet of Mars. What we want are the unique ages that are represented by the population**
#
# ```
# Input: [2,5,77,24,67,2,45,78,44,78,5,5,67,24]
# output: 2 5 24 44 45 67 77 78
# ```

# %%
##########################################################################################################
# Important point ::::                                                                                  ##
                                                                                                        ##
# Converting any list to a set and then again to list                                                   ##
# will change the order of the elements in the list,                                                    ##
# as the intermediate set will be scrambled randomly                                                    ##
# therefore, to not create conflicts in the received answers and our answer, we ask for a sorted list.  ##
                                                                                                        ##
##########################################################################################################

input_list = [2,5,77,24,67,2,45,78,44,78,5,5,67,24]

# remove duplicates (think Set)



# convert back to list and sort (so as not to create conflicts in the received answers and our answer)



# print the sorted list
