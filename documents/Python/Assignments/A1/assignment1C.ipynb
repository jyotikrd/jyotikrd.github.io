# %% [markdown]
# # Money Counter
# Write a program that asks the user to enter the following cash denominations and prints the total amount in \$
#
#
# ```
# Number of
# Cents =
# $1 bills =
# $10 bills =
# $20 bills =
# $50 bills =
# $100 bills =
# ```
#
#
# No space after $
#
# The desired output should be as follows **with 2 decimal places for every blank**:
#
# `You have a total amount of $___`

# %% [markdown]
# # Convert USD/INR
# Modify the above code below to convert the total amount calculated from all the denominations in \$ to INR (Indian Rupee). Use the exchange rate as \$1 = 76.26 INR
#
#
#
# ```
# Number of
# Cents =
# $1 bills =
# $10 bills =
# $20 bills =
# $50 bills =
# $100 bills =
# ```
#
#
#
#
# (Hint: Recall, type casting). No space after $ and a single pace before INR
#
#
# The desired output should be as follows **with 2 decimal places for amount in $ and integer value for INR**
#
#
# `You have a total amount of $__ which is equivalent to __ INR`
